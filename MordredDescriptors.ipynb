# %%
import deepchem as dc
from rdkit import Chem
import pandas as pd
import numpy as np

# %%
df_smiles = pd.read_csv('data/train/smiles_train.csv')

# %%
df_smiles
# Out:
#               MOFname                                             Smiles
# 0          mof_unit_1  O1/C(=C(\[C][CH]C(=O)O)/[C]C(=O)O)/O[Zn]23(O[C...
# 1          mof_unit_2  P([O])([O])C1=[C]C2=C(C=C([C]=[C]2)[CH])C(=C1)...
# 2          mof_unit_3  [C]1(C([CH2])([CH2])[CH2])O[Cu]234([Cu]([N]([C...
# 3          mof_unit_4  O1[C](O[V]2(O[C](O[V]1(O2)(O[C][C@@]12[C][C@H]...
# 4          mof_unit_5  [C]1(/C(=[C]\O)/[C]O)O[Cu]234([Cu](N([C]NC)[C]...
# ...               ...                                                ...
# 68608  mof_unit_68609  [C]1(/C(=[C]\C[C])/[C][CH]CCC)O[Zn]23(N([C]F)[...
# 68609  mof_unit_68610  [Ba](O[P@@](=O)([C](/C=C(\[C])/[P][O])[C])OCC)...
# 68610  mof_unit_68611  [C]1(c2c3c(c(cc2)C(=O)[O])cccc3)O[Cr@]23O[C](c...
# 68611  mof_unit_68612  C\1(=C/2\C=C[C]([C]3O[Cr](O[C](C(=[CH])[C][CH2...
# 68612  mof_unit_68613  C(=O)(/C(=[C]\I)/[C]([C])/C=C\[C])O[Cu@@](N1C(...
#
# [68613 rows x 2 columns]

# %%
smiles = df_smiles['Smiles']
featurizer = dc.feat.MordredDescriptors(ignore_3D=True)
features = featurizer.featurize(smiles)
# Out:
# C:\Users\User\anaconda3\envs\TMLCC\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# Failed to featurize datapoint 2, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 9, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 11, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 50, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 63, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 93, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 149, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 190, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 191, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 198, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 221, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 224, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 250, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 256, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 272, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 294, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 326, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 339, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 348, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 376, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 385, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 410, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 415, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 438, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 447, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 611, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 614, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 621, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 628, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 640, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 643, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 648, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 650, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 667, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 668, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 671, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 687, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 694, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 696, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 756, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 794, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 809, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 816, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 905, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 909, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1058, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1074, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1076, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1085, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1091, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1105, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1121, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1125, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1129, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1136, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1152, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1171, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1196, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1197, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1217, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1226, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1242, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1292, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1356, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1357, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1402, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1409, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1426, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1429, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1452, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1507, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1522, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1553, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1567, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1575, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1581, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1583, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1598, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1643, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1646, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1659, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1663, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1672, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1678, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1691, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1715, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1730, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1743, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1764, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1770, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1775, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1797, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1804, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1849, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1929, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1936, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1957, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1965, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1975, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1979, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1980, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2002, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2005, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2065, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2075, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2087, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2088, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2093, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2098, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2133, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2169, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2185, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2186, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2195, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2198, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2203, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2241, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2243, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2247, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2259, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2269, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2347, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2379, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2381, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2394, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2399, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2405, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2447, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2454, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2496, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2511, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2512, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2550, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2565, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2566, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2597, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2617, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2620, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2656, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2663, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2670, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2681, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2685, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2741, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2744, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2775, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2791, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2806, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2815, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2833, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2892, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 2907, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
# ...
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26668, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26677, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26680, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26709, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26822, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26838, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26851, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26854, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26913, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26948, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26949, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26983, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 26984, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27029, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27039, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27055, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27106, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27113, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27145, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27165, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27168, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27175, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27186, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27203, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27217, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27218, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27238, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27249, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27257, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27264, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27269, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27280, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27304, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27319, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27322, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27352, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27383, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27400, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27402, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27421, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27434, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27467, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27497, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27540, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27577, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27603, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27610, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27628, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27672, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 27702, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)

# %%
features.shape
