# %%
import deepchem as dc
from rdkit import Chem
import pandas as pd
import numpy as np
import pickle

# %%
df_smiles = pd.read_csv('data/pretest/smiles_pretest.csv')

# %%
df_smiles
# Out:
#                     MOFname                                             Smiles
# 0        mof_unit_pretest_1  [C]1(c2ccc(cc2)c2nnc(c3c(cc(cc3)[C]=O)OC[CH2])...
# 1        mof_unit_pretest_2  C\1(=C(/[C][CH2])\[CH])/O[Cu]234([Cu](N([C][CH...
# 2        mof_unit_pretest_3  [C]1(C2=CC=[C]C(=C2)[C]C=[CH])O[Zn]23(N4[CH]C=...
# 3        mof_unit_pretest_4  [C]1(c2c(c(c(c(c2)CC)[N])O)O)O[Cu]234([Cu](N5[...
# 4        mof_unit_pretest_5  [C]1([C])O[Zn]23([N])O[C](C([C](Cl)Cl)([CH2])[...
# ...                     ...                                                ...
# 1995  mof_unit_pretest_1996  C(=O)(c1ccc(cc1)[C]1O[Cu]234[Cu](O[C](c5c(cc(C...
# 1996  mof_unit_pretest_1997  [C]1([C])O[Cu]234([Cu]([N])(O[C]([C])O2)(O1)(O...
# 1997  mof_unit_pretest_1998  [C]1(c2c(c(c(c(c2N)C=O)[C])C=O)N)O[Cu]234([Cu]...
# 1998  mof_unit_pretest_1999  O1[C](O[Cu]234O[C](O[Cu]14(O[C](O2)/C=C(/C=C/C...
# 1999  mof_unit_pretest_2000  [Ba](OP(C1=C([C]=CC(=C1)[P@@](=O)(O[Ba]O[P@@](...
#
# [2000 rows x 2 columns]

# %%
smiles = df_smiles['Smiles']
featurizer = featurizer = dc.feat.RDKitDescriptors()
features = featurizer.featurize(smiles)
# Out:
# Failed to featurize datapoint 31, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 32, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 58, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 80, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 82, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 140, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 177, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 245, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 262, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 269, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 271, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 282, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 302, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 319, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 365, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 368, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 405, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 415, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 417, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 439, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 458, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 608, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 641, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 658, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 674, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 700, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 707, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 719, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 750, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 757, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 772, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 806, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 867, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 888, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 893, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 898, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 902, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 907, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 918, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 947, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 978, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1077, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1144, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1158, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1187, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1190, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1224, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1259, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1264, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1274, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1298, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1307, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1349, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1367, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1370, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1372, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1399, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1455, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1485, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1495, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1497, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1510, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1551, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1568, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1573, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1581, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# C:\Users\User\anaconda3\envs\TMLCC_CUDA\lib\site-packages\numpy\core\fromnumeric.py:1698: RuntimeWarning: overflow encountered in reduce
#   return asanyarray(a).trace(offset=offset, axis1=axis1, axis2=axis2, dtype=dtype, out=out)
# C:\Users\User\anaconda3\envs\TMLCC_CUDA\lib\site-packages\numpy\core\fromnumeric.py:1698: RuntimeWarning: invalid value encountered in reduce
#   return asanyarray(a).trace(offset=offset, axis1=axis1, axis2=axis2, dtype=dtype, out=out)
# Failed to featurize datapoint 1589, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1594, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1655, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1716, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1722, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1770, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1802, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1817, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1851, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# C:\Users\User\anaconda3\envs\TMLCC_CUDA\lib\site-packages\rdkit\Chem\Graphs.py:47: RuntimeWarning: invalid value encountered in multiply
#   Bn = An - res[n] * I
# C:\Users\User\anaconda3\envs\TMLCC_CUDA\lib\site-packages\rdkit\Chem\Graphs.py:47: RuntimeWarning: invalid value encountered in subtract
#   Bn = An - res[n] * I
# Failed to featurize datapoint 1861, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1879, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1885, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1911, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# Failed to featurize datapoint 1940, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(class RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True)
# C:\Users\User\anaconda3\envs\TMLCC_CUDA\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
nan_idx = []
for idx, i in enumerate(features):
    if len(i)==0:
        nan_idx.append(idx)
print(len(nan_idx))
# Out:
# 80

# %%
features[nan_idx] = np.NaN

# %%
pickle.dump(features, open('data/pretest/rdkit.pkl', 'wb'))
